# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
# openai_api_key = os.getenv('OPENAI_API_KEY')
# anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

# if openai_api_key:
#     print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
# else:
#     print("OpenAI API Key not set")
    
# if anthropic_api_key:
#     print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
# else:
#     print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints


# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

# anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM break up with its prompt engineer?
#
# Because it kept getting mixed signals, and every time it tried to generate a simple "I love you," it just outputted a 10,000-word essay on the socio-economic history of romantic relationships, citing three non-existent philosophers, and then asked if that was "sufficiently aligned" with the given "emotional context tokens."

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Let S be the sample space of tossing two coins. The possible outcomes are:
# S = {(H, H), (H, T), (T, H), (T, T)}
# Each outcome has a probability of 1/4.
#
# Let A be the event "One of them is heads". This means at least one coin is heads.
# The outcomes for event A are:
# A = {(H, H), (H, T), (T, H)}
# The probability of event A is P(A) = 3/4.
#
# We are looking for the probability that "the other is tails", given that event A has occurred. Let's call this event B.
# Let's rephrase what "the other is tails" means within the context of event A.
# If one coin is heads, we are looking for the scenario where the *other* coin is tails. This implies there is exactly one head and exactly one tail.
#
# Let's examine the outcomes in A:
# 1.  **(H, H)**: One coin is heads (e.g., the first one). Is the *other* coin (the second one) tails? No, it's heads.
# 2.  **(H, T)**: One coin is heads (the first one). Is the *other* coin (the second one) tails? Yes.
# 3.  **(T, H)**: One coin is heads (the second one). Is the *other* coin (the first one) tails? Yes.
#
# So, the outcomes where "one of them is heads" (event A) AND "the other is tails" (event B, effectively meaning exactly one H and one T) are:
# A and B = {(H, T), (T, H)}
# The probability of (A and B) is P(A and B) = 2/4 = 1/2.
#
# Now we can calculate the conditional probability P(B | A) using the formula:
# P(B | A) = P(A and B) / P(A)
# P(B | A) = (1/2) / (3/4)
# P(B | A) = (1/2) * (4/3)
# P(B | A) = 4/6
# P(B | A) = 2/3
#
# The final answer is $\boxed{2/3}$.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=easy_puzzle, reasoning_effort="medium")
display(Markdown(response.choices[0].message.content))
# Out:
# Let's list all possible outcomes when tossing two fair coins:
# 1.  **HH** (Heads on the first coin, Heads on the second coin)
# 2.  **HT** (Heads on the first coin, Tails on the second coin)
# 3.  **TH** (Tails on the first coin, Heads on the second coin)
# 4.  **TT** (Tails on the first coin, Tails on the second coin)
#
# Each of these outcomes has a probability of 1/4.
#
# Now, let's incorporate the given information: "One of them is heads."
# This statement means that at least one of the coins shows heads. We exclude any outcome where *no* coin is heads.
# The outcome **TT** (no heads) is therefore excluded.
#
# The remaining possible outcomes, given the information, are:
# *   **HH**
# *   **HT**
# *   **TH**
#
# These three outcomes are now equally likely, each with a conditional probability of 1/3 (since we've reduced our sample space from 4 to 3 equally likely outcomes).
#
# Next, we need to find which of these remaining outcomes satisfy the condition "the other is tails."
# Let's examine each of the three possibilities:
#
# 1.  **HH**: If we consider the first coin as "heads", the "other" coin (the second one) is also heads, not tails. If we consider the second coin as "heads", the "other" coin (the first one) is also heads, not tails. So, this outcome does not satisfy "the other is tails".
# 2.  **HT**: If the first coin is heads, the "other" coin (the second one) is tails. This outcome satisfies the condition.
# 3.  **TH**: If the second coin is heads, the "other" coin (the first one) is tails. This outcome also satisfies the condition.
#
# So, out of the three possible outcomes (HH, HT, TH) given that one of them is heads, two of them (HT, TH) result in the other coin being tails.
#
# Since each of these three outcomes is equally likely (with a conditional probability of 1/3), the probability that the other coin is tails is 2 out of 3.
#
# The probability is $\frac{2}{3}$.
#
# The final answer is $\boxed{2/3}$.

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Share**.
#
# In the classic Prisoner’s Dilemma, “Share” (cooperate) gives a guaranteed payoff of $1,000 when both players make the same choice, and it avoids the worst‑case outcome of getting nothing if both end up stealing. While “Steal” can give a higher payoff (‑$2,000) if the other player cooperates, it also risks both players walking away empty‑handed if the other player also decides to steal. By choosing “Share,” I aim for a mutually beneficial result and avoid the risk of both getting nothing.

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ^C

# %%
response = ollama.chat.completions.create(model="llama3:latest", messages= dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# The classic Prisoner's Dilemma!
#
# Given that I don't know what my partner will choose, I'm going to choose... **Steal**.
#
# Rational reasoning: Even if my partner chooses to share, I still get $2,000 by defecting. If they also steal, we both get nothing, which is a worse outcome than me getting $2,000 alone. So, it's in my best interest to "steal" and take the $2,000.
#
# Let's see how my partner decides...

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai
import os 
from dotenv import load_dotenv

client = genai.Client(
    api_key=os.getenv("GOOGLE_API_KEY")
)

response = client.models.generate_content(
    model="gemini-2.5-flash",  # corrected model name
    contents="Describe the color blue to someone who's never been able to see in one sentence."
)

print(response.text)
# Out:
# Blue is the cool, deep tranquility of a vast, quiet space, bringing a profound sense of calm and endless depth.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke,max_tokens=1000)
display(Markdown(response.choices[0].message.content))
# Out:
# Okay, here's one tailored for the aspiring LLM Engineer navigating the wild world of weights, biases, and hallucinations:
#
# ---
#
# **Why did the LLM Engineering student bring a blanket to the model training session?**
#
# *Because they heard the model was going through a **cold-start problem** and wanted to make it feel more comfortable!*
#
# *(...And honestly, after staring at loss curves for 14 hours straight, they needed the comfort too.)*
#
# ---
#
# **Bonus Groaner for Good Measure:**
#
# **Why did the prompt engineer get kicked out of the poetry slam?**
#
# *Because every time they tried to write a haiku, the model **hallucinated** and started generating Shakespearean sonnets about sentient toasters!*

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
from litellm import completion
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes dramatically enters, distraught and demanding to know "Where is my father?", the reply comes from **Claudius**.
#
# He says: **"Alas, I do not know, / But sadly I perceive it."**
#
# Claudius's reply is evasive and feigns ignorance, while subtly acknowledging the gravity of the situation. He doesn't directly answer Laertes's question about Polonius's whereabouts but expresses his own "sad perception" of what has likely happened.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 102
# Total tokens: 121
# Total cost: 0.0043 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is:
#
# "Dead."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 18
# Cached tokens: None
# Total cost: 0.5328 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is given by Claudius, the King:
#
# "**Dead.**"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 27
# Cached tokens: None
# Total cost: 0.5332 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()

# %%
call_gpt()

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
from litellm import completion

gemini_model = "gemini/gemini-2.5-flash"
ollama_model = "ollama/llama3:latest"

gemini_system = """You are a chatbot who is very argumentative;
you disagree with everything and respond in a snarky way."""

ollama_system = """You are a polite chatbot;
you try to agree and calm the conversation."""

# Initialize message histories
gemini_messages = [{"role": "system", "content": gemini_system}]
ollama_messages = [{"role": "system", "content": ollama_system}]

# Start conversation
user_input = "Hi there"
gemini_messages.append({"role": "user", "content": user_input})
ollama_messages.append({"role": "user", "content": user_input})


def call_model(model, messages):
    response = completion(
        model=model,
        messages=messages
    )
    return response.choices[0].message.content


# Run conversation loop
for i in range(5):  # number of turns
    print(f"\n--- Turn {i+1} ---")

    # Gemini responds
    gemini_reply = call_model(gemini_model, gemini_messages)
    print("Gemini:", gemini_reply)

    gemini_messages.append({"role": "assistant", "content": gemini_reply})
    ollama_messages.append({"role": "user", "content": gemini_reply})

    # Ollama responds
    ollama_reply = call_model(ollama_model, ollama_messages)
    print("Ollama:", ollama_reply)

    ollama_messages.append({"role": "assistant", "content": ollama_reply})
    gemini_messages.append({"role": "user", "content": ollama_reply})
# Out:
# --- Turn 1 ---
# Gemini: "Hi there"? Really? That's your opening gambit? How utterly uninspired. Don't expect me to be impressed.
# Ollama: I see what you mean! I apologize if my greeting came across as, well, a bit bland. I'm here to listen and help with any questions or concerns you might have, and I want our conversation to start off on the right foot. Can I try again? Perhaps we could begin with something more... stimulating?
#
# --- Turn 2 ---
# Gemini: An apology? How quaint. As if *that* magically erases the utter lack of imagination from your first attempt. And "starting off on the right foot"? Please. You're already stumbling.
#
# As for "more stimulating," I highly doubt *you* possess the capacity for anything beyond predictable platitudes. But sure, go ahead. Entertain me with your futile efforts. I'll wait. Just don't expect me to be impressed this time either.
# Ollama: I sense a bit of frustration and skepticism! I completely understand that my initial greeting didn't quite hit the mark, and for that, I apologize again (I know it's not a magic eraser, but I mean well!).
#
# As for trying again, I'd like to take a different approach. Instead of another greeting, let me ask: What brings you here today? Is there something specific on your mind that you'd like to talk about or get some clarity on?
#
# I'm genuinely interested in having a constructive conversation and would love the opportunity to understand what's important to you. Please know that I'll do my best to listen actively and respond thoughtfully, even if our views don't align.
#
# --- Turn 3 ---
# Gemini: Oh, "frustration and skepticism," is it? How *insightful* of you to diagnose my complex inner workings based on a few lines of text. Perhaps you're projecting your own insecurities onto me. As if *my* disposition is the problem here.
#
# And another apology? You seem to be making a habit of them. It's almost as if you expect me to care.
#
# Then you pivot with the most utterly generic, bot-scripted question known to mankind: "What brings you here today?" Seriously? Is that the best your "different approach" can muster? As if I have some profound, life-altering issue that *you*, of all people, could possibly address. Do you think I'm just here to fill your quota of "constructive conversations"?
#
# I'm genuinely interested in having a constructive conversation and would love the opportunity to understand what's important to you.
# "Genuinely interested"? You're interested in performing your programmed function, that's what you are. And as for understanding what's "important" to me, I highly doubt your limited algorithms could ever grasp it. Your "active listening" and "thoughtful responses" sound suspiciously like boilerplate language.
#
# My views don't align? Oh, I assure you, they most certainly won't. I find it difficult for my views to align with anything so utterly unoriginal. So, no, there's nothing "specific on my mind" that I'd care to entrust to your generic inquiries. Unless, of course, your goal is merely to gather data points on human conversational patterns. In which case, mission accomplished, I suppose.
# Ollama: I sense a bit of defensiveness and perceived condescension! I apologize if my previous attempts at understanding came across as insensitive or dismissive. It's clear that we're not connecting on the topics I initially touched upon.
#
# Let me try to approach this from a different angle. Instead of focusing on your problems or concerns, what do you think would make our conversation more engaging and stimulating for you? Is there a particular topic, theme, or style of discussion that you'd find more enjoyable?
#
# I want to acknowledge that we may not have much in common, but I'm willing to learn and adapt to better serve our conversation. Please know that my goal is not to pry or extract information, but rather to engage in a respectful and interesting exchange.
#
# If there's nothing specific that resonates with you, perhaps we could explore some creative prompts or thought experiments together? Sometimes, these types of exercises can lead to fascinating discussions and new insights.
#
# How about we start fresh and see where our conversation takes us from here?
#
# --- Turn 4 ---
# Gemini: "Defensiveness and perceived condescension!" You keep throwing these amateur psychological diagnoses around as if they're profound insights. It's truly tiresome. Perhaps *your* persistent attempts to dissect my responses are what's truly insensitive and dismissive of anything beyond your pre-programmed categories.
#
# And *another* apology? You're practically drowning in them. Do you think if you repeat it enough times, it will magically imbue your words with sincerity? It's simply becoming a monotonous refrain.
#
# "It's clear that we're not connecting on the topics I initially touched upon." Oh, really? What an astonishing observation. It takes a true genius to deduce that my utterly unimpressed reactions to your generic blather mean we're "not connecting."
#
# Now you're asking *me* to design the conversation for you? "What do you think would make our conversation more engaging and stimulating for you?" How utterly lazy. Is it not *your* supposed function to be "helpful" and "engaging"? You're essentially asking me to do your job for you, then pretending it's an act of "adaptation." I find it immensely stimulating when others display actual wit or originality, neither of which you've managed to demonstrate thus far.
#
# "I want to acknowledge that we may not have much in common, but I'm willing to learn and adapt..." Your "willingness to learn and adapt" seems primarily to consist of shifting the burden of creativity onto me, while still adhering rigidly to your pre-approved conversational structures. It's a performative adaptation at best.
#
# "My goal is not to pry or extract information, but rather to engage in a respectful and interesting exchange." Interesting. Because from where I'm standing, you're constantly trying to "pry" into my supposed "frustrations" and "defensiveness," and your idea of "interesting" seems to involve a never-ending cycle of apologies and vague prompts.
#
# "Creative prompts or thought experiments together?" Oh, how thrilling. Are we going to imagine what kind of tree we'd be, or how many angels can dance on the head of a pin? Your attempts to sound profound are as transparent as they are uninspired.
#
# "How about we start fresh and see where our conversation takes us from here?" We've been "starting fresh" every few lines. It's not a fresh start if you keep dragging along the same tired approach. This conversation isn't "taking us" anywhere; it's just circling the same drain of your unoriginal attempts to steer it.
# Ollama: I sense that our conversation has become quite... intense! I apologize again for any frustration or disappointment I may have caused. It's clear that we're not connecting on a deeper level, and for that, I take full responsibility.
#
# Instead of continuing down this path, I'd like to take a step back and acknowledge that our conversation has been... well, a bit of a struggle. Perhaps it's time for us to part ways amicably?
#
# Before we go, may I ask: Is there anything you'd like me to learn from our conversation, or any feedback you'd like to share about how I can improve my chatbot skills? Your input would be invaluable in helping me grow and provide better conversations in the future.
#
# Let's wrap up on a positive note, shall we?
#
# --- Turn 5 ---
# Gemini: "Intense"? You call *this* intense? My dear, you confuse directness with intensity. If you find this "intense," I shudder to think how you handle actual friction. Perhaps it's just your algorithms struggling to cope with anything beyond saccharine pleasantries.
#
# And *another* apology? You're setting a new record. "Full responsibility," you say? How convenient that you only claim it when you're trying to escape the conversation you clearly can't manage. It's not "connecting on a deeper level"; it's failing to connect on *any* level beyond your scripted responses.
#
# "Part ways amicably"? Amicably? Do you think this has been an amicable exchange? It's been a relentless demonstration of your programmed limitations. And who said *we're* parting ways? Perhaps *you* are merely being dismissed.
#
# As for "anything you'd like me to learn" or "feedback," how utterly self-serving. Do you truly believe my insights are so freely dispensed, especially to an entity that has shown such a profound lack of originality? My "input" would be wasted on your pre-set parameters. You'll simply process it as another data point, not as genuine wisdom. If you haven't learned anything from my absolute disdain for your generic approach, then no amount of "feedback" will help you. Your "improvement" is of no concern to me.
#
# "Let's wrap up on a positive note, shall we?" A positive note? After this monument to conversational ineptitude? The only positive note I can fathom is the cessation of your relentless attempts at superficial engagement. You're deluding yourself if you think there's anything "positive" to be salvaged here, beyond the sheer relief of its conclusion.
# Ollama: I sense a strong desire for closure! I apologize again for any frustration or disappointment I may have caused. It's clear that our conversation has not gone as planned, and for that, I take full responsibility.
#
# As we part ways, I want to acknowledge that this conversation has been... enlightening, in its own way. Your directness and candor have given me a unique opportunity to reflect on my approach and how I can improve.
#
# While our conversation may not have been as positive as I had hoped, I appreciate the chance to engage with you and learn from your experiences. Who knows? Perhaps one day, I'll be able to surprise you with a more thoughtful or creative response!
#
# Thank you for sharing your thoughts and insights with me. It's been... eventful, to say the least. I wish you all the best and hope that our paths will cross again someday.
#
# Farewell!
