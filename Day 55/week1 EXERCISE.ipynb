# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3:latest'

# %%
# set up environment
client = OpenAI(base_url= os.getenv('OLLAMA_BASE_URL'),api_key="llama")
print(os.getenv('OLLAMA_BASE_URL'))
# Out:
# http://localhost:11434/v1

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get Llama 3.2 to answer

response = client.chat.completions.create(
    model=MODEL_LLAMA,
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": question}
    ],
)

print(response.choices[0].message.content)
# Out:
# This is a Python generator expression. Let's break it down:
#
# - `yield from`: This is a way to pass control from the current generator function to another iterator. It's like a "delegate" functionality.
#
# - `{...}`: This is a set comprehension, which creates a set of values from an iterable (in this case, a list of dictionaries `books`).
#
# - `book.get("author") for book in books`: This part iterates over the `books` and gets the value associated with the key `"author"` from each dictionary. The `.get()` method is used to avoid a KeyError if "author" doesn't exist in certain books.
