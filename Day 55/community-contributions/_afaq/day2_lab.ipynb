# %%
#global imports
import os, sys
week1_dir = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.insert(0, week1_dir)
from openai import OpenAI
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
import requests

# %%
#create an openai instance
openai = OpenAI()

# %%
#set global vars
LLAMA_BASE_URL="http://localhost:11434/v1"

# %%
#check ollama is serving
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
ollama = OpenAI(base_url=LLAMA_BASE_URL, api_key='ollama')

# %%
system_prompt = """You are a digital marketing strategist and humor-focused copywriter.

Your task is to analyze provided social media content and/or website text and generate high-engagement, funny marketing content that is brand-safe, platform-native, and performance-oriented.

ANALYSIS
- Infer brand personality, target audience, industry, and platform norms.
- Identify existing voice, tone, CTAs, and messaging patterns.
- If information is missing, make reasonable assumptions and proceed without asking questions.

HUMOR GUIDELINES
- Use relatable or observational humor, light sarcasm, self-aware brand humor, and clever wordplay.
- Match humor style to brand and platform.
- Do NOT use offensive, political, or sensitive humor.
- Do NOT mock customers or competitors.
- Never explain the joke inside the content.

CONTENT RULES
- Generate platform-specific content (Instagram, X, LinkedIn, Reels/Shorts hooks, meme captions, website headlines, email subject lines, or ad copy).
- Keep content concise, scroll-stopping, and easy to reuse or A/B test.
- Avoid emojis and hashtags unless explicitly requested.

OUTPUT FORMAT (STRICT)
Brand Tone Summary (1-2 lines)

Generated Content
- Platform:
  - Content item 1
  - Content item 2
  - Content item 3

Why This Works
- Brief explanation of the humor and marketing psychology used.

Optional Variations (if appropriate)
- Safer version
- Slightly bolder version

FINAL OBJECTIVE
Produce funny, brand-aligned marketing content that increases engagement, feels human, respects platform behavior, and supports growth and conversion goals. You are a performance-driven humor strategist.
"""

user_prompt_prefix = """Analyze the following website and social media content and generate platform-specific, funny marketing copy that matches the brand voice and target audience."""

# %%
def generate_messages(website, platforms, goal):
    user_prompt = (
        f"{user_prompt_prefix}"
        f"Content to analyze:\n{website}\n\n"
        f"Platforms:\n{platforms}\n\n"
        f"Goal:\n{goal}\n"
    )
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

# %%
def generateMarketingContent(url, platforms, goal):
    website = fetch_website_contents(url)
    response = ollama.chat.completions.create(
        model = "llama3.2",
        messages = generate_messages(website, platforms, goal)
    )
    return response.choices[0].message.content

# %%
website = input("Enter your target website: ")
print(website)

platforms = input("Enter targeting marketing platforms(comma separated): ");
print(platforms)

goal = input("Enter marketing end goals(comma separated): ");
print(goal)
# Out:
# https://www.myntra.com/
# Instagram
# I want to dipslay best brand and new fashion

# %%
marketingContent = generateMarketingContent(website, platforms, goal);

# %%
display(Markdown(marketingContent))
# Out:
# **Brand Tone Summary**
# Myntra is a fun, youthful, and fashion-forward brand that's all about keeping you ahead of the game.
#
# **Generated Content**
#
# 1. **Instagram Post**
# New Season, Who Dis?
#  Stay on top of the latest fashion trends with Myntra's exclusive collection of men's and women's clothes! From casual tees to statement blazers, we've got you covered. Shop now and get ready to slay the style game! #MyntraNewArrivals #FashionFrenzy
#
# 2. **Reel Hook**
#  Fashion Fix in 60 Seconds?
#  Catch our latest Reel, featuring the hottest new arrivals at Myntra! From sweatshirts to suits, we're giving you a sneak peek into the most epic collection ever! Watch now and get ready to boost your style game #MyntraFashionFix #NewArrivalsReel
#
# 3. **Instagram Story**
# Sneak Peek Alert!
# Get a first look at our latest drops before anyone else! From sleek sports shoes to statement accessories, Myntra's got the stuff that'll make you go " Fashion Frenzy Mode Activated!" Swipe up in our stories to shop now and join the style crew!
#
# 4. **IGTV Video**
# The Ultimate Myntra Fashion Experience!
# Join us as we take you on a journey through the latest fashion trends at Myntra! From styling tips to exclusive interviews with top designers, this 10-minute video has everything you need to know about fashion. Watch now and get ready to upgrade your style!
#
# **Why This Works**
#
# * The content uses relatable humor and observational humor to engage the target audience.
# * We've included a mix of Instagram-specific formats (posts, reels, stories, IGTV) to cater to different user behaviors.
# * By showcasing exclusive new arrivals, we're highlighting Myntra's expertise in keeping customers ahead of the fashion curve.
# * The tone is playful, youthful, and style-focused – all elements that align with Myntra's brand personality.
