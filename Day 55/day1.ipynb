# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## Your first Frontier LLM Project
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### If necessary, install Cursor Extensions
#
# 1. From the View menu, select Extensions
# 2. Search for Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. Search for Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install if not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# imports

#To Read the .env file 
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI (or Ollama)
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# If you'd like to use free Ollama instead, please see the README section "Free Alternative to Paid APIs", and if you're not sure how to do this, there's a full solution in the solutions folder (day1_with_ollama.ipynb).
#
# ## Troubleshooting if you have problems:
#
# If you get a "Name Error" - have you run all cells from the top down? Head over to the Python Foundations guide for a bulletproof way to find and fix all Name Errors.
#
# If that doesn't fix it, head over to the [troubleshooting](../setup/troubleshooting.ipynb) notebook for step by step code to identify the root cause and fix it!
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = openai.chat.completions.create(model="gemini-2.5-flash", messages=messages)
response.choices[0].message.content
# Out:
# "Hi there! It's great to hear from you. Welcome!\n\nI'm ready when you are. How can I help you today? Or just tell me what's on your mind! 😊"

# %% [markdown]
# ## OK onwards with our first project

# %%
# Let's try out this utility

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 190 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer – RESOURCES
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents – RESOURCES
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production – RESOURCES
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook
# Subscribe to newsletter
# Type your email…
# Subscribe

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gemini-2.5-flash", messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 = 4'

# %% [markdown]
# ## And now let's build useful messages for GPT-4.1-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHome - Edward Donner\n\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of\nNebula.io\n. We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,\nacquired in 2021\n.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 190 countries. The\nfull curriculum is here\n. If you’re visiting from one of my courses – I’m super grateful!\nFebruary 17, 2026\nAI Coder: Vibe Coder to Agentic Engineer – RESOURCES\nJanuary 4, 2026\nAI Builder with n8n – Create Agents and Voice Agents – RESOURCES\nSeptember 15, 2025\nAI Engineering MLOps Track – Deploy AI to Production – RESOURCES\nMay 28, 2025\nWhich order to take the AI courses?\nNavigation\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nGet in touch\ned [at] edwarddonner [dot] com\nwww.edwarddonner.com\nFollow me\nLinkedIn\nTwitter\nFacebook\nSubscribe to newsletter\nType your email…\nSubscribe'}]

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gemini-2.5-flash",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# 'Welcome to the digital soapbox of Ed, a man so utterly obsessed with LLMs that his friends paid him to turn his incessant lecturing into Udemy courses. Apparently, he\'s quite good at it, having amassed 400,000 students who are likely now as proficient in AI as they are at nodding sagely at things they only half understand (just like Ed himself, bless him). When he\'s not revolutionizing career discovery with AI or making very amateur electronic music, he\'s busy outlining his future course schedule.\n\nSpeaking of which, here are the *latest* (future-dated) announcements:\n\n*   **February 17, 2026:** Get ready to transition from a "Vibe Coder" to an "Agentic Engineer." Deep.\n*   **January 4, 2026:** Learn to build AI and Voice Agents with n8n, because your LLMs need to speak up.\n*   **September 15, 2025:** An MLOps Track for deploying AI to production, because eventually, all those vibes need to do something real.\n*   **May 28, 2025:** A crucial guide on which order to take his AI courses. The suspense is unbearable.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# This website is a shrine to Edward Donner, a man who loves LLMs so much his friends begged him to turn his incessant droning into best-selling Udemy courses, saving them from endless AI lectures. He's also busy pitting LLMs against each other in a battle of wits, because apparently, human interaction just isn't cutting it anymore.
#
# The "news" section, curiously, features posts from the *future*, proving Ed is not only an AI expert but also a time traveler. Brace yourselves for "AI Coder: Vibe Coder to Agentic Engineer" coming February 2026, and "AI Builder with n8n" in January 2026. Apparently, we're all still trying to figure out "Which order to take the AI courses?" as late as May 2025. Good to know some things never change.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://cnn.com")
# Out:
# This website is apparently CNN, and it's a content smorgasbord, offering everything from "US" to "Space" to "Israel-Hamas War" — because who needs a focused news source when you can have *all* the news? Also, it's heavily concerned with whether their ads are working, which frankly, says a lot about the user experience. Prepare for an onslaught of headlines, assuming the video player doesn't freeze from an ad.

# %%
display_summary("https://anthropic.com")
# Out:
# Well, lookie here, it's Anthropic! Apparently, they're "securing the benefits and mitigating the risks" of AI, which basically means they're trying to make sure their super-smart AI, Claude (in all its Opus, Sonnet, and Haiku glory), doesn't accidentally take over the world.
#
# Speaking of world domination (or at least, *not* world domination), they've got some hot takes on "What 81,000 people want from AI" and even a statement from Dario Amodei on "Where things stand with the Department of War" (because nothing says "safe AI" like chatting with the War Department, right?). Plus, they just dropped Claude Sonnet 4.6, which is apparently their most capable Sonnet yet. You know, just in case you needed an AI that's even *better* at coding and professional work. What could possibly go wrong?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
#Read the JSON File
with open(r"C:\Users\sande\Desktop\Python\knowledge.json", "r", encoding="UTF-8") as f:
    raw_data = f.read()
print(raw_data)

from token import OP
from openai import OpenAI

# Step 1: Create your prompts
system_prompt = f"you are system consultant information india chatbot use this{raw_data}, please reply positive response, if you not find any answer ,sorry we will update it"
user_prompt = "Can You Check what are the SCII Policy ?"

# Step 2: Make the messages list
messages = [  
    {"role": "system", "content": system_prompt},
    {"role": "user", "content":user_prompt}
] 

# Step 3: Call OpenAI
response = openai.chat.completions.create(model="gemini-2.5-flash", messages=messages)
content = response.choices[0].message.content

# Step 4: print the result
print(content)
# Out:
# [
#   {
#     "label": "HomePage",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=HomePage",
#     "title": "Employee Portal | HomePage",
#     "content": "English (en)\nWelcome to SCII\nThe Glass Door Lock PIN will be updated every month.\nPIN for March 2026:\n\"1903\"\nDate\nDescription\n07-Mar-2025\nEvent:\nWomen’s Day\nDescription:\nThis is a special occasion to honor and appreciate the incredible women in our organization and their invaluable contributions.\nActivity:\nPlantation & Cake cutting\nCheck the photo gallery here.\n01-Jan-2025\nEvent:\nNew Year Cel

#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=MessagefromKSCDirector",
#     "title": "Employee Portal | MessagefromKSCDirector",
#     "content": "No language is assigned to this page.\nMessage from KSC Director\nMessage from Mr. Kodani, Managing Director of System Consultant Co. Ltd., Tokyo, Japan.\n1st Time Kodani San Speech On 20th October 2016\n2nd Time Kodani San Speech On 30th January 2017\n3rd Time Kodani San Speech On 19th May 2017\n4th Time Kodani San Speech On 12th September 2018"
#   },
#   {
#     "label": "PresidentMessage",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=President-message.php",
#     "title": "Employee Portal | President-message.php",
#     "content": "MgmtMsgs\nNo language is assigned to this page.\nFrom The Director's Desk\n\"I have been working with Indian engineers here at SCII since September 2013, involved in system development and global human resource development for Japanese companies. I am truly amazed every day at the excellence of Indian engineers and their speed of approaching new things. Combining KSC's vast knowledge-base of over 50 years of system development experience with the skills of young and talented Indian engineers, I want to create a new system development mechanism.\"\nMr. Junichi Kamiyama\nDirector,System Consultant Information India (P) Ltd."
#   },
#   {
#     "label": "OrgStructure",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=SCII%20Organization%20Structure",
#     "title": "Employee Portal | SCII Organization Structure",
#     "content": "No language is assigned to this page.\nSCII Organization Structure"
#   },
#   {
#     "label": "BuildingInfo",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Building%20Information",
#     "title": "Employee Portal | Building Information",
#     "content": "No language is assigned to this page.\nBuilding Information\nMain Building :\nSCII building is built in such a way that building is having proper space, good ventilation and\nproper sunlight. The ambience around the building is close to nature and help to provide employees with a calm environment to work.\nWorkplace/workstation :\nSCII building ensures congenial working condition. Office employees may concentrate their mind in\nwork under congenial working condition. A systematic arrangement of SCII office will give naturally\nmaximum efficiency at a minimum cost on all occasions.\nSecurity office:\nSafety and security are first, for that, in SCII we have well established security office. Security\noffice have record of all visitors on paper. This record should list the visitor’s name, company,\npurpose, time in, and time out. Video Surveillance is also available.\nCafeteria:\nCafeteria of SCII is a place where employees can have a short meeting with coffee, can have lunch\ntogether during lunch hours. It’s a neat & clean place with proper lighting and with beautiful\nscenery in front.\nGuest house:\nSCII company guest house is available with all required facilities.\nParking:\nSCII is having closed parking for two wheelers & open space parking for four wheelers. The parking is\nvery spacious and clean area which can accommodate all employees, vendor’s and visitor’s vehicles."
#   },
#   {
#     "label": "SeatEast",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Seat_East",
#     "title": "Employee Portal | Seat_East",
#     "content": "No language is assigned to this page.\nGround Floor East Office"
#   },
#   {
#     "label": "SeatWest",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Seat_West",
#     "title": "Employee Portal | Seat_West",
#     "content": "No language is assigned to this page.\nGround Floor West Office"
#   },
#   {
#     "label": "BackOffice",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Back%20Office",
#     "title": "Employee Portal | Back Office",
#     "content": "No language is assigned to this page.\nBack Office"
#   },
#   {
#     "label": "BackOfficeMembers",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=BackOffice%20Members",
#     "title": "Employee Portal | BackOffice Members",
#     "content": "No language is assigned to this page.\nBack Office Members\nSerial Number\nEmployee ID\nImages\nDetails\n01\n199004\nName:\nKamiyama Junichi\nEmail ID:\nj.kamiyama@scii.in\nDesignation:\nDirector\n02\n239010\nName:\nRyosuke Kuboki\nEmail ID:\nkuboki-ryosuke@ksc365.onmicrosoft.com\nDesignation:\nDirector\n03\n199002\nName:\nTsuchiya Toshimitsu\nEmail ID:\ntsuchiya@ksc.co.jp\nDesignation:\nIT Co-ordinator\n04\n148005\nName:\nPraveen T S\nEmail ID:\npraveen.301@scii.in\nDesignation:\nAccountant"
#   },
#   {
#     "label": "HRD",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page
#   },
#   {
#     "label": "NetworkMembers",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Network%20Members",
#     "title": "Employee Portal | Network Members",
#     "content": "No language is assigned to this page.\nISI Unit Members\nSerial Number\nEmployee ID\nDate Of Joining\nImages\nDetails\n01\n109003\n23-Jun-2010\nName:\nVijay Anand\nDesignation:\nSystem Administrator\nEmail ID:\nvijay.107@scii.in"
#   },
#   {
#     "label": "FacilitiesMembers",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Facilities%20Management%20Members",
#     "title": "Employee Portal | Facilities Management Members",
#     "content": "No language is assigned to this page.\nFacilities Team Members\nSerial Number\nEmployee ID\nDate Of Joining\nImages\nDetails\n01\n104002\n01-Apr-2010\nName:\nKamala kanth Muduli\nDesignation:\nAllied Jobs\n02\n149001\n26-May-2014\nName:\nNagalatha\nDesignation:\nAllied jobs\n03\n188004\n26-Sep-2018\nName:\nSiddharaju T S\nDesignation:\nGardener\n04\n199008\n26-Sep-2019\nName:\nNagaraju C\nDesignation:\nDriver\n05\n235009\n26-Sept-2023\nName:\nVenkatesh A C\nDesignation:\nDriver\n06\n252001\n26-Jan-2025\nName:\nDevaraju\nDesignation:\nElectrician"
#   },
#   {
#     "label": "IMS",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=IMS",
#     "title": "Employee Portal | IMS",
#     "content": "English (en)\nLast Updated - 15 July 2024\nIMS & PMS Handbook\nVer2.0\nContents\nPersonal Information Protection Management System\nThe need for the protection of personal information\nPersonal information handling practices\nPersonal Information Protection Policies and Procedures\nPersonal Information Protection document list\nPersonal Information Protection Policy\nOrganizational structure of the personal information protection\nAcquisition of personal information\nStorage\nDisposal\nResponding to complaints and consultation\nEmergency Situation\nManagement of information system\nEntry and Exit Management\nEducation\nInternal Audit\nRegarding penalties\nNotes related to Day to Day operations\nOffice space is off-limits for outsiders\nPersonal Address and Telephone details not to be revealed unnecessarily\nSwitch power off when leaving the PC unattended for long periods, like during lunch break\nObtain permission when taking-in or taking-out any equipment\nRecording media not to be brought in or taken out\nIn the event of loss or theft, report immediately to the person in charge\nDispose documents and recording media as per the rules\nWhen entrusting your data, be sure to enter into a contract\nComputer Usage\nEntry Permit (employee ID card)\nPrint outputs not to be left unattended\nApply security patch for OS etc\nDo not talk about work in public places"
#   },
#   {
#     "label": "RuleBook",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=RuleBook",
#     "title": "Employee Portal | RuleBook",
#     "content": "English (en)\nSYSTEM CONSULTANT INFORMATION INDIA (P) LTD.\nSTANDING ORDER FOR EMPLOYEES\nTABLE OF CONTENTS\nAPPLICATION\nDEFINITIONS\nRECRUITMENT\nCLASSIFICATION OF EMPLOYEES\nHIRING\nAPPOINTMENT IN SERVICE\nHIRING DOCUMENTS\nPROOF OF AGE OR DATE OF BIRTH\nPERMANENT HOME ADDRESS AND CHANGE OF ADDRESS\nME

#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=POSH",
#     "title": "Employee Portal | POSH",
#     "content": "English (en)\nPOSH Policy\n(Prevention of Sexual Harassment)\nContents\nObjective\nPhilosophy\nScope\nPolicy Description: Definitions\nGuidelines\nPolicy statement\nCore Values of POSH initiative\nThe Internal Committee\nEmployee Initiative\nTHIRD PARTY Harassment\nProcess Procedure in case of a Complaint of Sexual Harassment\nFrequently Asked Questions"
#   },
#   {
#     "label": "BusinessDays",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Business%20Days",
#     "title": "Employee Portal | Business Days",
#     "content": "No language is assigned to this page.\nENTRY & EXIT PROCEDURE\nBusiness Days\n|\nNon-Business Day\nGuidelines:\nTwo security Guards will be working at all time. During transition time, if there is only one Security guard, he will be responsible for job of both Security Guards.\nSCII Employees who have to work on a non-business day have to take permission from PM/Group Leader. The list of employees working on a non-business day (Holiday working list) will be given to Security Guards and Japanese Staff. Generally, only the persons in this list will be allowed to work on a non-business day.\nIn case of Emergency (when working on a holiday is not pre-scheduled), the staff coming to office have to take the permission from the Person In Charge on that day. If there is no Person In Charge, the Japanese staff who stays in the guest house will act as Person In Charge.\nA visitor will be accompanied by the company staff through out his/her stay in the building.\nAll the information has to be filled in the Visitor Information Register and Visitor Information Slip. Security Guard 1 has to make sure that the information is complete."
#   },
#   {
#     "label": "HealthInsurance",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=HealthInsurance",
#     "title": "Employee Portal | HealthInsurance",
#     "content": "No language is assigned to this page.\nGROUP HEALTH INSURANCE POLICY - POLICY SCHEDULE\nAttached to and forming part of Group Health Policy No 4101200700000227-00\nAdditional Conditions : Subject to the following additional Conditions and attached Clauses / Endorsements / Warranties :\n* Pre/Post Hospitalisation of 30/60 days respectively.\nCashless and Reimbursement Policy.\nPre-Existing Diseases exclusion waiver waived for all members, First 30 Days Exclusion waiver waived for all members. 1st Year exclusion waiver waived for all members.\nEmployees shall be covered from DOJ subject to availability of sufficient CD balance being maintained with insurer.\nAddition/deletion shall be done on prorata basis once in a month only subject to data being provided to us by 15th of succeeding month.\nMid term increase in SI is not allowed.\nNo individual can be covered more than once in the policy ? specifically if an employee and spouse are working for the same organization both cannot cover each other and cannot cover the same set of parents. In case at the time of claim it is found that the member is covered more than once, a deletion endorsement (without any refund) of such member will be effected to ensure he/she is covered only once.\nThe policy excludes treatment with or coverage of Inj- Bevacizumab (e.g Avastin) , Inj. Ranibizumab (e.g Lucentis). Injection Remicade, Oral Chemotherapy, Cyber Knife treatment, Stem cell therapy, Cochlear Implant Procedure, Femtolaser, Robotic surgery, Retrograde intra renal surgery, Lasik treatment for refractive error, Quantum magnetic resonance therapy, Toric Lens covered upto 30,000/- per eye, KT Laser Prostate, Holter monitoring unless otherwise specifically covered as per Policy Schedule.\nFor all admissible claims where treatment is taken at hospitals/nursing homes which are not in the list of network hospitals empanelled by the Company/Administrator, insured person shall bear 10% of the eligible admissible claim\nAdministration/ Registration/ Service Charges & Misc. Charges are not payable\n* Minimum and Maximum age at entry for Employee is 18 years and 65 years respectively.\nBaby cover from Day 1 Covered only after 90 Days of birth\nDomiciliary Hospitalization covered upto 20% of SI to a maximum of Rs. 20000\nRoom Rent Capping covered upto 2% of SI for Non-ICU & 3% of SI for ICU whichever is less. In an event of hospitalization into ICU or Non ICU room at rates exceeding the aforesaid limits, the reimbursement/payment of all other expenses incurred at the Hospital, with the exception of cost of medicines and implants, shall be made in the same proportion as the admissible room rate per day bears to the actual room rate per day (including but not limited to boarding and nursing  expenses).\nCoverage applicable is as per the benefit chart, annexure A attached along with.\nAll other terms and conditions as per Group Health Insurance Policy wordings as attached.\nImportant Note :\nPlease examine this Policy including its attachment Schedule/ Annexture if any. In the event of any discrepancy, contact the office of the Company immediately, it being noted that this policy shall be otherwise considered as being entirely in order.\nIn case of payment by cheque, in the event dishonor of cheque for any reason whatsover, insurance provided under this document automatically stands cancelled from the inception irrespective of whether a seperate communication is sent or not. Any claim arrising or related to consequences of the pre-existing disease is excluded from the scope of policy cover unless the same is covered on payment of premium and coverage terms mentioned in the schedule.\nThis is a Contract between the Company and the Insured Person(s). The Insured Person(s) shall not transfer, assign, alienate or in any way pass the benefits and /or liabilities to any other person, institution, hospital, company or body corporate without specific approval in writing by a duly authorised offic ...
#   },
#   {
#     "label": "Covid19Guidelines",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Covid19Guidelines",
#     "title": "Employee Portal | Covid19Guidelines",
#     "content": "English (en)\nGeneral Guidelines\nBefore coming to work each day, check if you are experiencing flu like symptoms\nIf Yes, Do not come to work, Inform your GL/Manager about the same.\nHow to Protect Yourself & Others(Prevention)\nWear face coverings at all times in office\nMaintain social distancing\nWash your hands often with soap and water for at least 20 seconds. Use an alcohol-based hand sanitizer that contains at least 60% alcohol if soap and water are not available.\nAvoid touching your eyes, nose, and mouth with unwashed hands.\nAvoid close contact with people who are sick.\nCover your cough or sneeze with a tissue, then throw the tissue in the trash.\nClean and disinfect frequently touched objects and surfaces.\nMaintain at least 1 meter (3 feet) distance between yourself and other people, particularly those who are coughing, sneezing and have a fever.\nStay home if you feel unwell.\nReporting Protocol\nHealth Status\nStep 1\nStep 2\nStep 3\nStep 4\nStep 5\nGL/Manager\nReporting each step to BackOffice\nEmployee is Covid Positive\nImmediately Inform your GL, Do not come to work.\nSend the positive report copy to GL.\nFollow doctors advice on road to recovery\nAfter recovery, get tested again.\nIf Positive , go back to step 2, If negative proceed to step 4\nSend the negative report to GL and await further instructions.\nSend mail\nTo : backoffice@scii.in\nCC : gl@scii.in, managers@scii.in\nFamily/ Flat mates/ room mates are covid postive(Applicable for all members in the Home/Room/Flat)\nImmediately Inform your GL, Do not come to work.\nGet tested for covid 19\nIf Positive Send report to GL Follow doctors advice on road to recovery, go to step 5\nIf Negative, Inform & send report to GL and await further instructions\nAfter recovery, get tested again.\nIf Positive , go back to step 3, If negative go to step 4\nSend mail\nTo : backoffice@scii.in\nCC : gl@scii.in, managers@scii.in\nContact With Someone Who’s Infected With COVID-19\nImmediately Inform your GL\nDo not come to work until further instructions\nSelf-quarantine\nMonitor yourself for known symptoms of Covid-19\nIf you observe onset of the symptoms in you or just want to confirm if you are infected, get yourself tested\nIf Positive Send report to GL Follow doctors advice on road to recovery, go to step 5\nIf Negative, Inform & send report to GL and await further instructions\nAfter recovery, get tested again.\nIf Positive , go back to step 3, If negative go to step
from CS Polytechnic backgrounds visited to get information about how the IT Industry works and what future opportunities will be.\nSeshadripuram College, Tumkur\n11-September-2024 and 12-September-2024\nSeshadripuram College, Tumkur\nStudents from MCA & MBA backgrounds visited to get information about how the IT Industry works and to understand the application of their skills in an industry. Management students gained knowledge of how different departments manage work.\nSIET Polytechnic College, Tumkur\n01-August-2024\nSIET Polytechnic College, Tumkur\nStudents from CS Polytechnic backgrounds visited to get information about how the IT Industry works, and what will be the future opportunities.\nVidya First Grade College, Tumkur\n29-July-2024\nVidya First Grade College, Tumkur\nStudents from BCA backgrounds visited to get information about how the IT Industry works and to understand the application of their skills in an industry.\nOxford Jain College, Tumkur\n03-July-2024\nOxford Jain College, Tumkur\nB.Com. & M.Com. students visited to get an insight into the current situation of industry, and corporate works. To know about our products and services, and to know, How IT Company works?\nGSSS College Mysore - 2024\n23-May-2024\nGSSS College Mysore\nStudents from ISE backgrounds visited to get information about how the IT Industry works and to understand the application of their skills in an industry that they have learned in their curriculum.\nPerformed an engaging team activity with our KSC employees, which allowed them to understand Japanese culture through interaction.\nSIET_20240215Batch\n15-02-2024\nSIET College, Tumkur\nPurpose of visit: Diploma (CS Branch) visited our campus to get information about how the IT Industry works and to understand the corporate environment. To understand how theoretical knowledge of their curriculum can be practically implemented in the IT sector.\nSIET_20240202Batch\n01-02-2024 and\n02-02-2024\nSIET College, Tumkur\nPurpose of visit: BE (CS Branch) visited our campus to get information about how the IT Industry works and to understand the corporate environment. To understand how theoretical knowledge of their curriculum can be practically implemented in the IT sector.\nSSIBM_2024Batch\n09-Jan-2024\nSri Siddhartha Institute of Business Management (SSIBM), Tumkur\nPurpose of visit: 36 M.Com. Students visited to understand the real-life challenges of any business establishment and how corporate environment will be\nGSSS College Mysore\n22-Dec-2023\nGSSS College Mysore\nPurpose of visit: 110 students visited to get information about how the IT Industry works and to understand the application of their skills in an industry that they have learned in their curriculum. Performed an engaging team activity for learning.\nSeshad ...
#   },
#   {
#     "label": "DownloadForm",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Download%20Form%20",
#     "title": "Employee Portal | Download Form",
#     "content": "No language is assigned to this page.\nDownload Forms\nSL No.\nForm Purpose\nDownload Here\n1\nUsed when employee works on holidays\nSCII Holiday Working Form\n2\nUsed when employee wants to connect external device\nExternal Connector Unlock\n3\nUsed when employee wants to bring in / take out devices\nSystem Declaration Obligation Form"
#   },
#   {
#     "label": "HolidayList",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=Holiday%20List",
#     "title": "Employee Portal | Holiday List",
#     "content": "No language is assigned to this page.\nLIST OF HOLIDAYS 2026\nUnder The Karnataka Shop And Establishment(National And Festival Holidays) Act 1963:\nSL No.\nDate\nDay Of The Week\nName Of The Festival/Holiday\nImages\n1\n14th JAN\nWEDNESDAY\nMAKARA SHANKRANTI\n2\n26th JAN\nMONDAY\nREPUBLIC DAY\n3\n19th MAR\nTHURSDAY\nUGADI\n4\n20th MAR\nFRIDAY\nIDUL FITR/ RAMZAN\n5\n03rd APR\nFRIDAY\nGOOD FRIDAY\n6\n01st MAY\nFRIDAY\nMAY DAY\n7\n26th JUN\nFRIDAY\nMUHARRAM\n8\n14th SEPT\nMONDAY\nGANESHA CHATURTI\n9\n02nd OCT\nFRIDAY\nGANDHI JAYANTHI\n10\n20th OCT\nTUESDAY\nVIJAYADASHAMI/DASARA\n11\n09th NOV\nMONDAY\nDEEPAVALI\n12\n25th DEC\nFRIDAY\nCHRISTMAS DAY"
#   },
#   {
#     "label": "KSCHoliday",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=KSCHoliday",
#     "title": "Employee Portal | KSCHoliday",
#     "content": "English (en)\nLIST OF KSC HOLIDAYS 2026\nSL No.\nDate\nDay Of The Week\nName Of The Festival/Holiday\n1\n01-01-2026\nTHURSDAY\nNew Year's Day\n2\n02-01-2026\nFRIDAY\nNew Year Holidays\n3\n12-01-2026\nMONDAY\nComing of Age Day\n4\n11-02-2026\nWEDNESDAY\nNational Foundation Day\n5\n23-02-2026\nMONDAY\nEmperor's Birthday\n6\n20-03-2026\nFRIDAY\nVernal Equinox Day\n7\n29-04-2026\nWEDNESDAY\nShowa Day\n8\n03-05-2026\nSUNDAY\nConstitution Memorial Day\n9\n04-05-2026\nMONDAY\nGreenery Day\n10\n05-05-2026\nTUESDAY\nChildren's Day\n11\n06-05-2026\nWEDNESDAY\nSubstitute Holiday\n12\n20-07-2026\nMONDAY\nMarine Day\n13\n11-08-2026\nTUESDAY\nMountain Day\n14\n21-09-2026\nMONDAY\nRespect for the Aged Day\n15\n22-09-2026\nTUESDAY\nHoliday\n16\n23-09-2026\nWEDNESDAY\nAutumnal Equinox Day\n17\n12-10-2026\nMONDAY\nSports Day\n18\n03-11-2026\nTUESDAY\nCulture Day\n19\n23-11-2026\nMONDAY\nLabor Thanksgiving Day\n20\n30-12-2026\nWEDNESDAY\nYear-End Holidays\n21\n31-12-2026\nTHURSDAY\nYear-End Holidays"
#   },
#   {
#     "label": "NewEmpInfo",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=NewEmpInfo",
#     "title": "Employee Portal | NewEmpInfo",
#     "content": "No language is assigned to this page.\nNew Employee Information:-\nInformation\nSCII Freshers 2022 September Batch\nSCII Freshers 2021 September Batch\nSCII Freshers 2020 October Batch\nSCII Freshers 2019 August Batch\nSCII Freshers 2018 August Batch\nSCII Freshers 2017 August Batch"
#   },
#   {
#     "label": "SCIIClub",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=SCIIClub",
#     "title": "Employee Portal | SCIIClub",
#     "content": "No language is assigned to this page.\nSCII CLUB\nSCII Club is a part of SCII organization,\nHaving a motive of providing a relief or stress free relaxation to the employees.\nBeing a part of SCII,\nSCII club welcomes the new ideas from employees.\nCheck out the Entertainment Events from the below link\nEntertainment events"
#   },
#   {
#     "label": "EBooks",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=EBooks",
#     "title": "Employee Portal | EBooks",
#     "content": "English (en)\nE-Book Index:\nDate\nE-Book Title\n06-08-2021\nProject To Product, by Mik Kersten"
#   },
#   {
#     "label": "SCIILibrary",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=SCIILibrary",
#     "title": "Employee Portal | SCIILibrary",
#     "content": "No language is assigned to this page.\nSCII LIBRARY\nContact Person:\n-\n-\nClick here to view SCII book list\nLibrary Rules & Regulations\n1.\tWhen the Employee needs to borrow the books, ask the Library Management member to open the lock of the book shelf which is located in GF Open Space East\n.\n2.\tAfter taking book from the shelf, the Employee needs to sign the registration book, which is kept by the Library Management member, by agreeing with the rules of lending books.\n3.\tIf the Employee fails to find the book which the Employee needs in the book shelf, then the Employee can find the person who has borrowed the book from the registration book.\n4.\tThe Employee should not sublet the books to other person.\nThe registration book has to be maintained properly.\n5.\tThe Employee can take the books home, but have to bring the books to the office every working day.\n6.\tA Book will be issued for 30 days only. However, issued books may be recalled earlier, if urgently required by the Library. If member wants to keep it for more than 30 days, he/she needs to renew it.\n7.\tA Book must be returned in the same condition in which it was issued.\n8.\tIn case of marking/underlining / folding of pages of books, the cost of the latest edition of the book will be charged from the borrower.\n9.\tThe Library Management member should check the book shelf once every month to take the inventory of all books.\nRules of lending Library\nI agree with the following rules and borrow the books.\n•\tI will handle the books carefully.\n•\tI will compensate the books in case of losing the books or damaging the books.\n•\tI will not sublet the books the third person.\n•\tEven if I take the books home, I will bring the books to the office every working day."
#   },
#   {
#     "label": "NewsArchive",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=NewsArchive",
#     "title": "Employee Portal | NewsArchive",
# ...
#   },
#   {
#     "label": "KSC2014April",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=KSC2014April",
#     "title": "Employee Portal | KSC2014April",
#     "content": "No language is assigned to this page.\nKSC Freshers 2014(April) Batch\nName:\nTANOKA SAEKO\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Her:\nShe is from Yamagata Prefecture\nShe has graduated in Human Culture\nHer hobbies are Sleeping, Reading, Shopping and Drawing Pictures.\nShe likes to eat Sushi.\nIf god grant her few Wishes:\nShe want to go to space.\nShe want to develop a system which should be helpfull to all.\nShe feels India is very Hot and likes India's nature which is different form Japan's\nName:\nENDO MINAMI\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Her:\nShe is from Tokyo\nShe has graduated in LAW\nShe lived in America for few years.\nHer hobbies are Travelling, Shoping and Archery.\nShe likes to eat Sushi, Pasta and Naan.\nIf god grant her few Wishes:\nShe want to travel all around the world.\nShe want to go back to past (Before Christ)\nShe want to live happily without working.\nFunniest situation was thinking about the funniest situation.\nShe just want to lead a normal life.\nShe feels Indians are very friendly than she thought, India is very Hot and Humid, likes Indian nature\nName:\nKIYOHARA ANNA\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Her:\nShe is from Kumamoto\nShe has graduated in LAW\nHer hobbies are watching Movies,Playing Piano and Flute,  Japanese Animation.\nIf god grant her few Wishes:\nShe want to meet Johny Depp.\nShe want to swim with Shark.\nShe want to be a good System Engineer.\nShe feels Indians are very kind, She want to learn Indian culture.\nName:\nSATO HARUNA\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Her:\nShe is from Kanagawa Prefecture.\nShe has graduated in Political Science and Economics.\nHer hobbies are playing Trumphet.\nShe likes to eat Sushi.\nIf god grant her few Wishes:\nShe want to to make friends all around the world.\nShe want to enjoy the work for the whole working life.\nShe want to teach people about Software.\nShe has worked as a teacher for 4 years teaching English and Mathematics.\nFunniest situation was when her brother had dialled 911 and with in few minutes the rescue squad had called back her home for enquire.\nBack"
#   },
#   {
#     "label": "KSC2013May",
#     "url": "http://10.17.2.248:1234/scii/tiki-index.php?page=KSC2013May",
#     "title": "Employee Portal | KSC2013May",
#     "content": "No language is assigned to this page.\nKSC Freshers 2013(May) Batch\nPhoto gallery(Interview).\nName:\nKIYOTAKA IGA\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Tokyo.\nHe likes to watch non-fiction and romantic movies.\nHis hobby is playing Saxophone and he is playing from past 14 years.\nHis favorite game is Football.\nHe likes J-Pop and Classical music.\nHe likes Sushi and Kabab(boneless).\nPlaces he  would like to visit is USA, Disney Land and New york.\nHis aim in life is to make 10 close friends.\nName:\nYUTA OISHI\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Shizouka\nHis hobbies are playing tennis, playing guitar and reading books.\nHe likes Japanese rock music.\nHis favorite food are Sushi and Tandoori Chicken.\nHis aim in life is to have house and to be good Engineer.\nName:\nTAKAFUMI KADOSAWA\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Tokyo.\nHis hobbies are driving father's car, listening to music, playing guitar and playing dart.\nHis favorite game is Baseball.\nHe likes Rock, pop and punk music.\nHis favorite food is Curry.\nPlace he would like to visit is Okinawi.\nName:\nISAO SAKAI\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Saitama Prefecture.\nHis hobbies are playing Tennis and Japanese Archery.\nHe likes Japanese pop.\nHis favorite food are Japanese rice and Tandoori Chicken.\nHe would like to visit to America in future.\nName:\nKENTA SAKAI\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Tokyo.\nHis favorite game is Soccer.\nHis three wishes are  to win lottery, want to eat Japanese food and want to be good Soccer Player.\nHis best moment after arriving in India is Lunch time when he speaks with Indians.\nHe likes Shabu Shabu and Chicken Kabab.\nHe won match for Soccers Tokyo team.\nPlace he would like to visit is Italy.\nName:\nKEITA SHIMIZU\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Chiba.\nHis hobby is to grow vegetables in the pot.\nHis favorite game is Baseball.\nHe likes Japanese pop music.\nHis favorite food is Sushi,Butter curry and Butter naan.\nHe would like to visit Europe.\nName:\nTAKAHIRO SUZUKI\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Chiba.\nHis hobby is reading books and Skating.\nHe likes Japanese pop music.\nHe would like to visit Italy.\nName:\nTAKAYUKI NAKAHARA\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Yamaguchi.\nHe likes to play Football.\nHis favorite game is Soccer.\nHis favorite music is B-Z.\nHis favorite food is Noodles with Soup and butter naan.\nHe would like to visit America.\nHe loves to travel around the world and communicate with different people.\nName:\nSHUN MASAKI\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Kanagawa near Tokyo.\nHis hobby is playing darts.\nHe likes J-pop music.\nBest moment when he arrived INDIA was learning about Indian god and religion.\nHe likes Curry-Rice and Indian chicken tandoori.\nHe would like to visit Great Britain.\nName:\nMASAKI MIZOTA\nEmployee ID:\nDesignation:\nTrainee Software Engineer\nAbout Him:\nHe is from Chiba.\nHis Hobby is Playing Guitar.\nHis favorite game is Soccer and Baseball.\nHe likes Rock Music.\nHis favorite food is Sushi and Butter Chicken.\nHe would like to visit Italy in future.\nBack"
#   }
# ]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[33], line 20
#      14 messages = [
#      15     {"role": "system", "content": system_prompt},
#      16     {"role": "user", "content":user_prompt}
#      17 ]
#      19 # Step 3: Call OpenAI
# ---> 20 response = openai.chat.completions.create(model="gemini-2.5-flash", messages=messages)
#      21 content = response.choices[0].message.content
#      23 # Step 4: print the result
#
# File c:\Users\sande\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\sande\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File c:\Users\sande\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\sande\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 9.38934669s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '9s'}]}}]

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
